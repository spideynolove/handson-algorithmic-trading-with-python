# %%
# Pandas data structures

# %%
# Series

# %%
import pandas as pd

# %%
ser1 = pd.Series(range(1, 6)); ser1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ser2 = pd.Series(range(1, 6), index=['a', 'b', 'c', 'd', 'e']); ser2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
ser3 = pd.Series({ 'a': 1.0, 'b': 2.0, 'c': 3.0, 'd': 4.0, 'e': 5.0 }); ser3
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
ser3.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
ser3.values
# Out:
# array([1., 2., 3., 4., 5.])

# %%
ser3.name = 'Alphanumeric'; ser3
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# Name: Alphanumeric, dtype: float64

# %%
# DataFrame

# %%
df1 = pd.DataFrame({'A': range(1,5,1), 'B': range(10,50,10), 'C': range(100, 500, 100)}); df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
df2 = pd.DataFrame({'A': range(1,5,1), 'B': range(10,50,10), 'C': range(100, 500, 100)}, index=['a', 'b', 'c', 'd']); df2
# Out:
#    A   B    C
# a  1  10  100
# b  2  20  200
# c  3  30  300
# d  4  40  400

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df2.values
# Out:
# array([[  1,  10, 100],
#        [  2,  20, 200],
#        [  3,  30, 300],
#        [  4,  40, 400]])

# %%
df2['D'] = range(1000,5000,1000); df2
# Out:
#    A   B    C     D
# a  1  10  100  1000
# b  2  20  200  2000
# c  3  30  300  3000
# d  4  40  400  4000

# %%
df2.index.name = 'lowercase'; df2
# Out:
#            A   B    C     D
# lowercase
# a          1  10  100  1000
# b          2  20  200  2000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.columns.name = 'uppercase'; df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          2  20  200  2000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
# Index

# %%
ind1 = pd.Index(range(5)); ind1
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ind2 = pd.Index(list(range(5))); ind2
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
#ind2[0] = -1

# %%
# Essential Pandas operations

# %%
# Indexing, Selection and Filtering

# %%
df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          2  20  200  2000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2['B']
# Out:
# lowercase
# a    10
# b    20
# c    30
# d    40
# Name: B, dtype: int64

# %%
df2[['A', 'C']]
# Out:
# uppercase  A    C
# lowercase
# a          1  100
# b          2  200
# c          3  300
# d          4  400

# %%
df2[(df2['D'] > 1000) & (df2['D'] <= 3000)]
# Out:
# uppercase  A   B    C     D
# lowercase
# b          2  20  200  2000
# c          3  30  300  3000

# %%
df2.loc[['c', 'd']]
# Out:
# uppercase  A   B    C     D
# lowercase
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.iloc[[0]]
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000

# %%
df2[df2['D'] == 2000] = 0; df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          0   0    0     0
# c          3  30  300  3000
# d          4  40  400  4000

# %%
# Dropping entries

# %%
df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          0   0    0     0
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.drop('b')
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          0   0    0     0
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.drop('b', inplace=True); df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.drop(['a', 'd'])
# Out:
# uppercase  A   B    C     D
# lowercase
# c          3  30  300  3000

# %%
df2.drop(['A', 'B'], axis=1)
# Out:
# uppercase    C     D
# lowercase
# a          100  1000
# c          300  3000
# d          400  4000

# %%
# Sorting and Ranking

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(5,5), index=np.random.randint(0, 100, size=5), columns=np.random.randint(0, 100, size=5)); df
# Out:
#           94        36        45        8         41
# 76  0.768887 -0.236478  0.202421 -1.331029  1.004895
# 99  0.168503  0.312535  1.997330 -0.065295  0.235346
# 54 -2.091867 -0.838102  0.423356  0.155802  0.114433
# 2  -0.044240  0.768799 -0.744272 -1.164473  0.619387
# 36 -0.020873  0.003611 -0.035679 -1.283123 -1.802094

# %%
df.sort_index()
# Out:
#           94        36        45        8         41
# 2  -0.044240  0.768799 -0.744272 -1.164473  0.619387
# 36 -0.020873  0.003611 -0.035679 -1.283123 -1.802094
# 54 -2.091867 -0.838102  0.423356  0.155802  0.114433
# 76  0.768887 -0.236478  0.202421 -1.331029  1.004895
# 99  0.168503  0.312535  1.997330 -0.065295  0.235346

# %%
df.sort_index(axis=1)
# Out:
#           8         36        41        45        94
# 76 -1.331029 -0.236478  1.004895  0.202421  0.768887
# 99 -0.065295  0.312535  0.235346  1.997330  0.168503
# 54  0.155802 -0.838102  0.114433  0.423356 -2.091867
# 2  -1.164473  0.768799  0.619387 -0.744272 -0.044240
# 36 -1.283123  0.003611 -1.802094 -0.035679 -0.020873

# %%
df.sort_values(by=df.columns[0])
# Out:
#           94        36        45        8         41
# 54 -2.091867 -0.838102  0.423356  0.155802  0.114433
# 2  -0.044240  0.768799 -0.744272 -1.164473  0.619387
# 36 -0.020873  0.003611 -0.035679 -1.283123 -1.802094
# 99  0.168503  0.312535  1.997330 -0.065295  0.235346
# 76  0.768887 -0.236478  0.202421 -1.331029  1.004895

# %%
df.rank()
# Out:
#      94   36   45   8    41
# 76  5.0  2.0  3.0  1.0  5.0
# 99  4.0  4.0  5.0  4.0  3.0
# 54  1.0  1.0  4.0  5.0  2.0
# 2   2.0  5.0  1.0  3.0  4.0
# 36  3.0  3.0  2.0  2.0  1.0

# %%
# Arithmetic operations

# %%
df1 = pd.DataFrame(np.random.randn(3,2), index=['A', 'C', 'E'], columns=['colA', 'colB']); df1
# Out:
#        colA      colB
# A -0.817013 -0.519728
# C -1.571520  0.706102
# E  0.220347  0.619867

# %%
df2 = pd.DataFrame(np.random.randn(4,3), index=['A', 'B', 'C', 'D'], columns=['colA', 'colB', 'colC']); df2
# Out:
#        colA      colB      colC
# A -0.208747 -0.446596  2.048557
# B -0.583783 -0.055171 -0.134256
# C -0.218170  2.237855 -1.062263
# D  0.709081  0.600751 -1.928858

# %%
df1 + df2
# Out:
#        colA      colB  colC
# A -1.025760 -0.966324   NaN
# B       NaN       NaN   NaN
# C -1.789691  2.943957   NaN
# D       NaN       NaN   NaN
# E       NaN       NaN   NaN

# %%
df1.add(df2, fill_value=0)
# Out:
#        colA      colB      colC
# A -1.025760 -0.966324  2.048557
# B -0.583783 -0.055171 -0.134256
# C -1.789691  2.943957 -1.062263
# D  0.709081  0.600751 -1.928858
# E  0.220347  0.619867       NaN

# %%
df1
# Out:
#        colA      colB
# A -0.817013 -0.519728
# C -1.571520  0.706102
# E  0.220347  0.619867

# %%
df2
# Out:
#        colA      colB      colC
# A -0.208747 -0.446596  2.048557
# B -0.583783 -0.055171 -0.134256
# C -0.218170  2.237855 -1.062263
# D  0.709081  0.600751 -1.928858

# %%
df1 - df2[['colB']]
# Out:
#    colA      colB
# A   NaN -0.073133
# B   NaN       NaN
# C   NaN -1.531754
# D   NaN       NaN
# E   NaN       NaN

# %%
# Advanced Pandas operations

# %%
# Merging and combining

# %%
df1.index.name = 'Index'; df1.columns.name = 'Columns'; df1
# Out:
# Columns      colA      colB
# Index
# A       -0.817013 -0.519728
# C       -1.571520  0.706102
# E        0.220347  0.619867

# %%
df2.index.name = 'Index'; df2.columns.name = 'Columns'; df2
# Out:
# Columns      colA      colB      colC
# Index
# A       -0.208747 -0.446596  2.048557
# B       -0.583783 -0.055171 -0.134256
# C       -0.218170  2.237855 -1.062263
# D        0.709081  0.600751 -1.928858

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
# Columns    colA_x    colB_x    colA_y    colB_y      colC
# Index
# A       -0.817013 -0.519728 -0.208747 -0.446596  2.048557
# C       -1.571520  0.706102 -0.218170  2.237855 -1.062263

# %%
pd.merge(df1, df2, left_index=True, right_index=True, suffixes=('_1', '_2'))
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A       -0.817013 -0.519728 -0.208747 -0.446596  2.048557
# C       -1.571520  0.706102 -0.218170  2.237855 -1.062263

# %%
pd.merge(df1, df2, left_index=True, right_index=True, suffixes=('_1', '_2'), how='outer')
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A       -0.817013 -0.519728 -0.208747 -0.446596  2.048557
# B             NaN       NaN -0.583783 -0.055171 -0.134256
# C       -1.571520  0.706102 -0.218170  2.237855 -1.062263
# D             NaN       NaN  0.709081  0.600751 -1.928858
# E        0.220347  0.619867       NaN       NaN       NaN

# %%
df1.merge(df2, left_index=True, right_index=True, suffixes=('_1', '_2'), how='outer')
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A       -0.817013 -0.519728 -0.208747 -0.446596  2.048557
# B             NaN       NaN -0.583783 -0.055171 -0.134256
# C       -1.571520  0.706102 -0.218170  2.237855 -1.062263
# D             NaN       NaN  0.709081  0.600751 -1.928858
# E        0.220347  0.619867       NaN       NaN       NaN

# %%
df1.join(df2, lsuffix='_1', rsuffix='_2')
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A       -0.817013 -0.519728 -0.208747 -0.446596  2.048557
# C       -1.571520  0.706102 -0.218170  2.237855 -1.062263
# E        0.220347  0.619867       NaN       NaN       NaN

# %%
pd.concat([df1, df2])
# Out:
# Columns      colA      colB      colC
# Index
# A       -0.817013 -0.519728       NaN
# C       -1.571520  0.706102       NaN
# E        0.220347  0.619867       NaN
# A       -0.208747 -0.446596  2.048557
# B       -0.583783 -0.055171 -0.134256
# C       -0.218170  2.237855 -1.062263
# D        0.709081  0.600751 -1.928858

# %%
pd.concat([df1, df2], axis=1)
# Out:
# Columns      colA      colB      colA      colB      colC
# Index
# A       -0.817013 -0.519728 -0.208747 -0.446596  2.048557
# C       -1.571520  0.706102 -0.218170  2.237855 -1.062263
# E        0.220347  0.619867       NaN       NaN       NaN
# B             NaN       NaN -0.583783 -0.055171 -0.134256
# D             NaN       NaN  0.709081  0.600751 -1.928858

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
# Columns      colA      colB      colC
# 0       -0.817013 -0.519728       NaN
# 1       -1.571520  0.706102       NaN
# 2        0.220347  0.619867       NaN
# 3       -0.208747 -0.446596  2.048557
# 4       -0.583783 -0.055171 -0.134256
# 5       -0.218170  2.237855 -1.062263
# 6        0.709081  0.600751 -1.928858

# %%
# Hierarchial indexing

# %%
df = pd.DataFrame(np.random.randn(10, 2), index=[list('aaabbbccdd'), [1, 2, 3, 1, 2, 3, 1, 2, 1, 2]], columns=['A', 'B']); df
# Out:
#             A         B
# a 1 -0.771751 -0.816941
#   2 -0.770137  1.206837
#   3 -0.441487 -0.174131
# b 1 -1.497138 -2.109181
#   2  0.487884  0.040656
#   3  0.357891  1.432895
# c 1 -1.416903  0.834398
#   2 -1.937445 -0.058739
# d 1 -0.577735 -0.253905
#   2 -0.970618 -1.734612

# %%
df.index.names = ['alpha', 'numeric']; df
# Out:
#                       A         B
# alpha numeric
# a     1       -0.771751 -0.816941
#       2       -0.770137  1.206837
#       3       -0.441487 -0.174131
# b     1       -1.497138 -2.109181
#       2        0.487884  0.040656
#       3        0.357891  1.432895
# c     1       -1.416903  0.834398
#       2       -1.937445 -0.058739
# d     1       -0.577735 -0.253905
#       2       -0.970618 -1.734612

# %%
df.reset_index()
# Out:
#   alpha  numeric         A         B
# 0     a        1 -0.771751 -0.816941
# 1     a        2 -0.770137  1.206837
# 2     a        3 -0.441487 -0.174131
# 3     b        1 -1.497138 -2.109181
# 4     b        2  0.487884  0.040656
# 5     b        3  0.357891  1.432895
# 6     c        1 -1.416903  0.834398
# 7     c        2 -1.937445 -0.058739
# 8     d        1 -0.577735 -0.253905
# 9     d        2 -0.970618 -1.734612

# %%
df.unstack()
# Out:
#                 A                             B
# numeric         1         2         3         1         2         3
# alpha
# a       -0.771751 -0.770137 -0.441487 -0.816941  1.206837 -0.174131
# b       -1.497138  0.487884  0.357891 -2.109181  0.040656  1.432895
# c       -1.416903 -1.937445       NaN  0.834398 -0.058739       NaN
# d       -0.577735 -0.970618       NaN -0.253905 -1.734612       NaN

# %%
df.stack()
# Out:
# alpha  numeric
# a      1        A   -0.771751
#                 B   -0.816941
#        2        A   -0.770137
#                 B    1.206837
#        3        A   -0.441487
#                 B   -0.174131
# b      1        A   -1.497138
#                 B   -2.109181
#        2        A    0.487884
#                 B    0.040656
#        3        A    0.357891
#                 B    1.432895
# c      1        A   -1.416903
#                 B    0.834398
#        2        A   -1.937445
#                 B   -0.058739
# d      1        A   -0.577735
#                 B   -0.253905
#        2        A   -0.970618
#                 B   -1.734612
# dtype: float64

# %%
df.stack().index
# Out:
# MultiIndex([('a', 1, 'A'),
#             ('a', 1, 'B'),
#             ('a', 2, 'A'),
#             ('a', 2, 'B'),
#             ('a', 3, 'A'),
#             ('a', 3, 'B'),
#             ('b', 1, 'A'),
#             ('b', 1, 'B'),
#             ('b', 2, 'A'),
#             ('b', 2, 'B'),
#             ('b', 3, 'A'),
#             ('b', 3, 'B'),
#             ('c', 1, 'A'),
#             ('c', 1, 'B'),
#             ('c', 2, 'A'),
#             ('c', 2, 'B'),
#             ('d', 1, 'A'),
#             ('d', 1, 'B'),
#             ('d', 2, 'A'),
#             ('d', 2, 'B')],
#            names=['alpha', 'numeric', None])

# %%
# Grouping

# %%
df = df.reset_index(); df
# Out:
#   alpha  numeric         A         B
# 0     a        1 -0.771751 -0.816941
# 1     a        2 -0.770137  1.206837
# 2     a        3 -0.441487 -0.174131
# 3     b        1 -1.497138 -2.109181
# 4     b        2  0.487884  0.040656
# 5     b        3  0.357891  1.432895
# 6     c        1 -1.416903  0.834398
# 7     c        2 -1.937445 -0.058739
# 8     d        1 -0.577735 -0.253905
# 9     d        2 -0.970618 -1.734612

# %%
grouped = df[['A','B']].groupby(df['alpha']); grouped

# %%
grouped.describe()
# Out:
#           A                                                              \
#       count      mean       std       min       25%       50%       75%
# alpha
# a       3.0 -0.661125  0.190214 -0.771751 -0.770944 -0.770137 -0.605812
# b       3.0 -0.217121  1.110431 -1.497138 -0.569624  0.357891  0.422887
# c       2.0 -1.677174  0.368078 -1.937445 -1.807309 -1.677174 -1.547039
# d       2.0 -0.774176  0.277810 -0.970618 -0.872397 -0.774176 -0.675956
#
#                     B                                                    \
#             max count      mean       std       min       25%       50%
# alpha
# a     -0.441487   3.0  0.071922  1.034082 -0.816941 -0.495536 -0.174131
# b      0.487884   3.0 -0.211877  1.784490 -2.109181 -1.034262  0.040656
# c     -1.416903   2.0  0.387829  0.631544 -0.058739  0.164545  0.387829
# d     -0.577735   2.0 -0.994258  1.047018 -1.734612 -1.364435 -0.994258
#
#
#             75%       max
# alpha
# a      0.516353  1.206837
# b      0.736775  1.432895
# c      0.611114  0.834398
# d     -0.624082 -0.253905

# %%
grouped.apply(pd.DataFrame.unstack)
# Out:
# alpha
# a      A  0   -0.771751
#           1   -0.770137
#           2   -0.441487
#        B  0   -0.816941
#           1    1.206837
#           2   -0.174131
# b      A  3   -1.497138
#           4    0.487884
#           5    0.357891
#        B  3   -2.109181
#           4    0.040656
#           5    1.432895
# c      A  6   -1.416903
#           7   -1.937445
#        B  6    0.834398
#           7   -0.058739
# d      A  8   -0.577735
#           9   -0.970618
#        B  8   -0.253905
#           9   -1.734612
# dtype: float64

# %%
grouped[['A', 'B']].agg('mean')
# Out:
#               A         B
# alpha
# a     -0.661125  0.071922
# b     -0.217121 -0.211877
# c     -1.677174  0.387829
# d     -0.774176 -0.994258

# %%
from scipy import stats
grouped[['A', 'B']].transform(stats.zscore)
# Out:
#           A         B
# 0 -0.712297 -1.052750
# 1 -0.701904  1.344170
# 2  1.414201 -0.291419
# 3 -1.411789 -1.302172
# 4  0.777582  0.173320
# 5  0.634207  1.128852
# 6  1.000000  1.000000
# 7 -1.000000 -1.000000
# 8  1.000000  1.000000
# 9 -1.000000 -1.000000

# %%
# Data transformation and missing data

# %%
# Transforming axis indices

# %%
df2
# Out:
# Columns      colA      colB      colC
# Index
# A       -0.208747 -0.446596  2.048557
# B       -0.583783 -0.055171 -0.134256
# C       -0.218170  2.237855 -1.062263
# D        0.709081  0.600751 -1.928858

# %%
df2.index = ['Alpha', 'Beta', 'Gamma', 'Delta']; df2
# Out:
# Columns      colA      colB      colC
# Alpha   -0.208747 -0.446596  2.048557
# Beta    -0.583783 -0.055171 -0.134256
# Gamma   -0.218170  2.237855 -1.062263
# Delta    0.709081  0.600751 -1.928858

# %%
df2.index = df2.index.map(lambda x : x[:3]); df2
# Out:
# Columns      colA      colB      colC
# Alp     -0.208747 -0.446596  2.048557
# Bet     -0.583783 -0.055171 -0.134256
# Gam     -0.218170  2.237855 -1.062263
# Del      0.709081  0.600751 -1.928858

# %%
df2.rename(index={'Alp': 0, 'Bet': 1, 'Gam': 2, 'Del': 3}, columns={'colA': 'A', 'colB': 'B', 'colC': 'C'})
# Out:
# Columns         A         B         C
# 0       -0.208747 -0.446596  2.048557
# 1       -0.583783 -0.055171 -0.134256
# 2       -0.218170  2.237855 -1.062263
# 3        0.709081  0.600751 -1.928858

# %%
# Dealing with missing data

# %%
# Filtering

# %%
for row, col in [('Bet', 'colA'), ('Bet', 'colB'), ('Bet', 'colC'), ('Del', 'colB'), ('Gam', 'colC')]:
    df2.at[row, col] = np.NaN

df2
# Out:
# Columns      colA      colB      colC
# Alp     -0.208747 -0.446596  2.048557
# Bet           NaN       NaN       NaN
# Gam     -0.218170  2.237855       NaN
# Del      0.709081       NaN -1.928858

# %%
df2.isnull()
# Out:
# Columns   colA   colB   colC
# Alp      False  False  False
# Bet       True   True   True
# Gam      False  False   True
# Del      False   True  False

# %%
df2.notnull()
# Out:
# Columns   colA   colB   colC
# Alp       True   True   True
# Bet      False  False  False
# Gam       True   True  False
# Del       True  False   True

# %%
df2.dropna(how='all')
# Out:
# Columns      colA      colB      colC
# Alp     -0.208747 -0.446596  2.048557
# Gam     -0.218170  2.237855       NaN
# Del      0.709081       NaN -1.928858

# %%
df2.dropna(how='any')
# Out:
# Columns      colA      colB      colC
# Alp     -0.208747 -0.446596  2.048557

# %%
# Filling in

# %%
df2
# Out:
# Columns      colA      colB      colC
# Alp     -0.208747 -0.446596  2.048557
# Bet           NaN       NaN       NaN
# Gam     -0.218170  2.237855       NaN
# Del      0.709081       NaN -1.928858

# %%
df2.fillna(method='backfill', inplace=True); df2
# Out:
# /tmp/ipykernel_54363/585395643.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method='backfill', inplace=True); df2
# Columns      colA      colB      colC
# Alp     -0.208747 -0.446596  2.048557
# Bet     -0.218170  2.237855 -1.928858
# Gam     -0.218170  2.237855 -1.928858
# Del      0.709081       NaN -1.928858

# %%
# Transformation using functions/mapping

# %%
df2['Category'] = ['HIGH', 'LOW', 'LOW', 'HIGH']; df2
# Out:
# Columns      colA      colB      colC Category
# Alp     -0.208747 -0.446596  2.048557     HIGH
# Bet     -0.218170  2.237855 -1.928858      LOW
# Gam     -0.218170  2.237855 -1.928858      LOW
# Del      0.709081       NaN -1.928858     HIGH

# %%
df2['Category'] = df2['Category'].map({'HIGH': 'H', 'LOW': 'L'}); df2
# Out:
# Columns      colA      colB      colC Category
# Alp     -0.208747 -0.446596  2.048557        H
# Bet     -0.218170  2.237855 -1.928858        L
# Gam     -0.218170  2.237855 -1.928858        L
# Del      0.709081       NaN -1.928858        H

# %%
df2.drop('Category', axis=1).applymap(np.exp)
# Out:
# /tmp/ipykernel_54363/1821130222.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df2.drop('Category', axis=1).applymap(np.exp)
# Columns      colA      colB      colC
# Alp      0.811601  0.639803  7.756697
# Bet      0.803988  9.373208  0.145314
# Gam      0.803988  9.373208  0.145314
# Del      2.032122       NaN  0.145314

# %%
# Discretization

# %%
arr = np.random.randn(10); arr
# Out:
# array([ 0.727189  , -1.87103931,  0.15932997,  0.06696856, -0.615838  ,
#        -0.94496985, -0.68118334, -0.3655173 ,  0.43515047, -2.02691243])

# %%
cat = pd.cut(arr, bins=5, labels=['Very Low', 'Low', 'Med', 'High', 'Very High']); cat
# Out:
# ['Very High', 'Very Low', 'High', 'High', 'Med', 'Low', 'Med', 'High', 'Very High', 'Very Low']
# Categories (5, object): ['Very Low' < 'Low' < 'Med' < 'High' < 'Very High']

# %%
pd.DataFrame({'Value': arr, 'Category': cat})
# Out:
#       Value   Category
# 0  0.727189  Very High
# 1 -1.871039   Very Low
# 2  0.159330       High
# 3  0.066969       High
# 4 -0.615838        Med
# 5 -0.944970        Low
# 6 -0.681183        Med
# 7 -0.365517       High
# 8  0.435150  Very High
# 9 -2.026912   Very Low

# %%
qcat = pd.qcut(arr, q=5, labels=['Very Low', 'Low', 'Med', 'High', 'Very High']); qcat
# Out:
# ['Very High', 'Very Low', 'High', 'High', 'Med', 'Low', 'Low', 'Med', 'Very High', 'Very Low']
# Categories (5, object): ['Very Low' < 'Low' < 'Med' < 'High' < 'Very High']

# %%
pd.DataFrame({'Value': arr, 'Category': cat, 'Quartile Category': qcat})
# Out:
#       Value   Category Quartile Category
# 0  0.727189  Very High         Very High
# 1 -1.871039   Very Low          Very Low
# 2  0.159330       High              High
# 3  0.066969       High              High
# 4 -0.615838        Med               Med
# 5 -0.944970        Low               Low
# 6 -0.681183        Med               Low
# 7 -0.365517       High               Med
# 8  0.435150  Very High         Very High
# 9 -2.026912   Very Low          Very Low

# %%
pd.cut(arr, bins=5).categories
# Out:
# IntervalIndex([ (-2.03, -1.476], (-1.476, -0.925], (-0.925, -0.374],
#                 (-0.374, 0.176],   (0.176, 0.727]],
#               dtype='interval[float64, right]')

# %%
pd.qcut(arr, q=5).categories
# Out:
# IntervalIndex([ (-2.028, -1.13],  (-1.13, -0.642], (-0.642, -0.193],
#                 (-0.193, 0.214],   (0.214, 0.727]],
#               dtype='interval[float64, right]')

# %%
# Permutations and sampling

# %%
df = pd.DataFrame(np.random.randn(10,5), index=np.sort(np.random.randint(0, 100, size=10)), columns=list('ABCDE')); df
# Out:
#            A         B         C         D         E
# 5  -0.760949  0.275363  0.600306  0.483160 -1.672512
# 5   1.511530 -1.268053 -1.566086 -0.896276 -1.004432
# 22 -1.364872 -0.497911 -0.472058  0.408080 -2.246102
# 47  0.812921  0.890319 -1.168839 -0.159941 -0.864603
# 82 -1.034799 -0.110756 -0.223968  0.487025 -2.513716
# 89 -1.434199 -0.762035  0.646054 -0.096858  0.372309
# 89 -1.199700 -1.414473 -0.314075  1.194605  0.721268
# 90  0.805204  0.116758 -0.536140  0.942574 -0.219538
# 94 -1.017580  0.851011  0.624516 -1.551725 -0.648053
# 97  0.085759  1.264719 -3.077832  1.674024 -1.820806

# %%
df.loc[np.random.permutation(df.index)]
# Out:
#            A         B         C         D         E
# 89 -1.434199 -0.762035  0.646054 -0.096858  0.372309
# 89 -1.199700 -1.414473 -0.314075  1.194605  0.721268
# 5  -0.760949  0.275363  0.600306  0.483160 -1.672512
# 5   1.511530 -1.268053 -1.566086 -0.896276 -1.004432
# 94 -1.017580  0.851011  0.624516 -1.551725 -0.648053
# 5  -0.760949  0.275363  0.600306  0.483160 -1.672512
# 5   1.511530 -1.268053 -1.566086 -0.896276 -1.004432
# 89 -1.434199 -0.762035  0.646054 -0.096858  0.372309
# 89 -1.199700 -1.414473 -0.314075  1.194605  0.721268
# 47  0.812921  0.890319 -1.168839 -0.159941 -0.864603
# 97  0.085759  1.264719 -3.077832  1.674024 -1.820806
# 82 -1.034799 -0.110756 -0.223968  0.487025 -2.513716
# 22 -1.364872 -0.497911 -0.472058  0.408080 -2.246102
# 90  0.805204  0.116758 -0.536140  0.942574 -0.219538

# %%
df.iloc[np.random.randint(0, len(df), size=5)]
# Out:
#           A         B         C         D         E
# 5   1.51153 -1.268053 -1.566086 -0.896276 -1.004432
# 94 -1.01758  0.851011  0.624516 -1.551725 -0.648053
# 89 -1.19970 -1.414473 -0.314075  1.194605  0.721268
# 94 -1.01758  0.851011  0.624516 -1.551725 -0.648053
# 94 -1.01758  0.851011  0.624516 -1.551725 -0.648053

# %%
# File operations and Pandas

# %%
# Text files

# %%
# Writing

# %%
df.to_csv('df.csv', sep=',', header=True, index=True)

# %%
# !head -n 4 df.csv
# Out:
# ,A,B,C,D,E
# 5,-0.7609494782935838,0.2753632008353459,0.6003062600082448,0.4831595446564573,-1.6725118762402025
# 5,1.5115299252959997,-1.2680525936215488,-1.5660858563873754,-0.8962756729986886,-1.0044318400161611
# 22,-1.3648717765956895,-0.4979106326715105,-0.4720575886638758,0.40808009166660614,-2.2461023808867866

# %%
# Reading

# %%
pd.read_csv('df.csv', sep=',', index_col=0, nrows=5)
# Out:
#            A         B         C         D         E
# 5  -0.760949  0.275363  0.600306  0.483160 -1.672512
# 5   1.511530 -1.268053 -1.566086 -0.896276 -1.004432
# 22 -1.364872 -0.497911 -0.472058  0.408080 -2.246102
# 47  0.812921  0.890319 -1.168839 -0.159941 -0.864603
# 82 -1.034799 -0.110756 -0.223968  0.487025 -2.513716

# %%
pd.read_csv('df.csv', sep=',', index_col=0, chunksize=2)

# %%
list(pd.read_csv('df.csv', sep=',', index_col=0, chunksize=2))
# Out:
# [          A         B         C         D         E
#  5 -0.760949  0.275363  0.600306  0.483160 -1.672512
#  5  1.511530 -1.268053 -1.566086 -0.896276 -1.004432,
#             A         B         C         D         E
#  22 -1.364872 -0.497911 -0.472058  0.408080 -2.246102
#  47  0.812921  0.890319 -1.168839 -0.159941 -0.864603,
#             A         B         C         D         E
#  82 -1.034799 -0.110756 -0.223968  0.487025 -2.513716
#  89 -1.434199 -0.762035  0.646054 -0.096858  0.372309,
#             A         B         C         D         E
#  89 -1.199700 -1.414473 -0.314075  1.194605  0.721268
#  90  0.805204  0.116758 -0.536140  0.942574 -0.219538,
#             A         B         C         D         E
#  94 -1.017580  0.851011  0.624516 -1.551725 -0.648053
#  97  0.085759  1.264719 -3.077832  1.674024 -1.820806]

# %%
# JSON files

# %%
df.iloc[:4]
# Out:
#            A         B         C         D         E
# 5  -0.760949  0.275363  0.600306  0.483160 -1.672512
# 5   1.511530 -1.268053 -1.566086 -0.896276 -1.004432
# 22 -1.364872 -0.497911 -0.472058  0.408080 -2.246102
# 47  0.812921  0.890319 -1.168839 -0.159941 -0.864603

# %%
# df.iloc[:4].to_json('df.json')
df.iloc[:4].to_json('df.json', orient='records')

# %%
# !cat df.json
# Out:
# [{"A":-0.7609494783,"B":0.2753632008,"C":0.60030626,"D":0.4831595447,"E":-1.6725118762},{"A":1.5115299253,"B":-1.2680525936,"C":-1.5660858564,"D":-0.896275673,"E":-1.00443184},{"A":-1.3648717766,"B":-0.4979106327,"C":-0.4720575887,"D":0.4080800917,"E":-2.2461023809},{"A":0.8129207539,"B":0.8903185929,"C":-1.1688388955,"D":-0.1599407454,"E":-0.8646034912}]

# %%
pd.read_json('df.json')
# Out:
#           A         B         C         D         E
# 0 -0.760949  0.275363  0.600306  0.483160 -1.672512
# 1  1.511530 -1.268053 -1.566086 -0.896276 -1.004432
# 2 -1.364872 -0.497911 -0.472058  0.408080 -2.246102
# 3  0.812921  0.890319 -1.168839 -0.159941 -0.864603
