# %%
# Pandas data structures

# %%
# Series

# %%
import pandas as pd

# %%
ser1 = pd.Series(range(1, 6)); ser1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ser2 = pd.Series(range(1, 6), index=['a', 'b', 'c', 'd', 'e']); ser2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
ser3 = pd.Series({ 'a': 1.0, 'b': 2.0, 'c': 3.0, 'd': 4.0, 'e': 5.0 }); ser3
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
ser3.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
ser3.values
# Out:
# array([1., 2., 3., 4., 5.])

# %%
ser3.name = 'Alphanumeric'; ser3
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# Name: Alphanumeric, dtype: float64

# %%
# DataFrame

# %%
df1 = pd.DataFrame({'A': range(1,5,1), 'B': range(10,50,10), 'C': range(100, 500, 100)}); df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
df2 = pd.DataFrame({'A': range(1,5,1), 'B': range(10,50,10), 'C': range(100, 500, 100)}, index=['a', 'b', 'c', 'd']); df2
# Out:
#    A   B    C
# a  1  10  100
# b  2  20  200
# c  3  30  300
# d  4  40  400

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df2.values
# Out:
# array([[  1,  10, 100],
#        [  2,  20, 200],
#        [  3,  30, 300],
#        [  4,  40, 400]])

# %%
df2['D'] = range(1000,5000,1000); df2
# Out:
#    A   B    C     D
# a  1  10  100  1000
# b  2  20  200  2000
# c  3  30  300  3000
# d  4  40  400  4000

# %%
df2.index.name = 'lowercase'; df2
# Out:
#            A   B    C     D
# lowercase
# a          1  10  100  1000
# b          2  20  200  2000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.columns.name = 'uppercase'; df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          2  20  200  2000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
# Index

# %%
ind1 = pd.Index(range(5)); ind1
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ind2 = pd.Index(list(range(5))); ind2
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
#ind2[0] = -1

# %%
# Essential Pandas operations

# %%
# Indexing, Selection and Filtering

# %%
df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          2  20  200  2000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2['B']
# Out:
# lowercase
# a    10
# b    20
# c    30
# d    40
# Name: B, dtype: int64

# %%
df2[['A', 'C']]
# Out:
# uppercase  A    C
# lowercase
# a          1  100
# b          2  200
# c          3  300
# d          4  400

# %%
df2[(df2['D'] > 1000) & (df2['D'] <= 3000)]
# Out:
# uppercase  A   B    C     D
# lowercase
# b          2  20  200  2000
# c          3  30  300  3000

# %%
df2.loc[['c', 'd']]
# Out:
# uppercase  A   B    C     D
# lowercase
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.iloc[[0]]
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000

# %%
df2[df2['D'] == 2000] = 0; df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          0   0    0     0
# c          3  30  300  3000
# d          4  40  400  4000

# %%
# Dropping entries

# %%
df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          0   0    0     0
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.drop('b')
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# b          0   0    0     0
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.drop('b', inplace=True); df2
# Out:
# uppercase  A   B    C     D
# lowercase
# a          1  10  100  1000
# c          3  30  300  3000
# d          4  40  400  4000

# %%
df2.drop(['a', 'd'])
# Out:
# uppercase  A   B    C     D
# lowercase
# c          3  30  300  3000

# %%
df2.drop(['A', 'B'], axis=1)
# Out:
# uppercase    C     D
# lowercase
# a          100  1000
# c          300  3000
# d          400  4000

# %%
# Sorting and Ranking

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(5,5), index=np.random.randint(0, 100, size=5), columns=np.random.randint(0, 100, size=5)); df
# Out:
#           55        2         32        22        20
# 42 -0.119869  0.129108 -1.534263  0.185077  0.696696
# 41 -0.615252 -1.189886 -1.748312 -1.069783  0.317867
# 34  1.843848 -0.937563 -1.525346 -1.042739  0.344631
# 9   1.411735  1.511092  0.663650  0.344064  0.179283
# 94 -0.194162 -0.428078 -0.528475  0.125906 -1.447981

# %%
df.sort_index()
# Out:
#           55        2         32        22        20
# 9   1.411735  1.511092  0.663650  0.344064  0.179283
# 34  1.843848 -0.937563 -1.525346 -1.042739  0.344631
# 41 -0.615252 -1.189886 -1.748312 -1.069783  0.317867
# 42 -0.119869  0.129108 -1.534263  0.185077  0.696696
# 94 -0.194162 -0.428078 -0.528475  0.125906 -1.447981

# %%
df.sort_index(axis=1)
# Out:
#           2         20        22        32        55
# 42  0.129108  0.696696  0.185077 -1.534263 -0.119869
# 41 -1.189886  0.317867 -1.069783 -1.748312 -0.615252
# 34 -0.937563  0.344631 -1.042739 -1.525346  1.843848
# 9   1.511092  0.179283  0.344064  0.663650  1.411735
# 94 -0.428078 -1.447981  0.125906 -0.528475 -0.194162

# %%
df.sort_values(by=df.columns[0])
# Out:
#           55        2         32        22        20
# 41 -0.615252 -1.189886 -1.748312 -1.069783  0.317867
# 94 -0.194162 -0.428078 -0.528475  0.125906 -1.447981
# 42 -0.119869  0.129108 -1.534263  0.185077  0.696696
# 9   1.411735  1.511092  0.663650  0.344064  0.179283
# 34  1.843848 -0.937563 -1.525346 -1.042739  0.344631

# %%
df.rank()
# Out:
#      55   2    32   22   20
# 42  3.0  4.0  2.0  4.0  5.0
# 41  1.0  1.0  1.0  1.0  3.0
# 34  5.0  2.0  3.0  2.0  4.0
# 9   4.0  5.0  5.0  5.0  2.0
# 94  2.0  3.0  4.0  3.0  1.0

# %%
# Arithmetic operations

# %%
df1 = pd.DataFrame(np.random.randn(3,2), index=['A', 'C', 'E'], columns=['colA', 'colB']); df1
# Out:
#        colA      colB
# A  0.927388 -1.372988
# C -1.563857  2.096890
# E -1.235737 -1.230761

# %%
df2 = pd.DataFrame(np.random.randn(4,3), index=['A', 'B', 'C', 'D'], columns=['colA', 'colB', 'colC']); df2
# Out:
#        colA      colB      colC
# A -1.068520 -0.942017 -0.034613
# B  1.194072  0.365779  0.259961
# C  0.573401  1.035832  1.610257
# D -0.334471 -0.224601  1.311413

# %%
df1 + df2
# Out:
#        colA      colB  colC
# A -0.141132 -2.315006   NaN
# B       NaN       NaN   NaN
# C -0.990456  3.132723   NaN
# D       NaN       NaN   NaN
# E       NaN       NaN   NaN

# %%
df1.add(df2, fill_value=0)
# Out:
#        colA      colB      colC
# A -0.141132 -2.315006 -0.034613
# B  1.194072  0.365779  0.259961
# C -0.990456  3.132723  1.610257
# D -0.334471 -0.224601  1.311413
# E -1.235737 -1.230761       NaN

# %%
df1
# Out:
#        colA      colB
# A  0.927388 -1.372988
# C -1.563857  2.096890
# E -1.235737 -1.230761

# %%
df2
# Out:
#        colA      colB      colC
# A -1.068520 -0.942017 -0.034613
# B  1.194072  0.365779  0.259961
# C  0.573401  1.035832  1.610257
# D -0.334471 -0.224601  1.311413

# %%
df1 - df2[['colB']]
# Out:
#    colA      colB
# A   NaN -0.430971
# B   NaN       NaN
# C   NaN  1.061058
# D   NaN       NaN
# E   NaN       NaN

# %%
# Advanced Pandas operations

# %%
# Merging and combining

# %%
df1.index.name = 'Index'; df1.columns.name = 'Columns'; df1
# Out:
# Columns      colA      colB
# Index
# A        0.927388 -1.372988
# C       -1.563857  2.096890
# E       -1.235737 -1.230761

# %%
df2.index.name = 'Index'; df2.columns.name = 'Columns'; df2
# Out:
# Columns      colA      colB      colC
# Index
# A       -1.068520 -0.942017 -0.034613
# B        1.194072  0.365779  0.259961
# C        0.573401  1.035832  1.610257
# D       -0.334471 -0.224601  1.311413

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
# Columns    colA_x    colB_x    colA_y    colB_y      colC
# Index
# A        0.927388 -1.372988 -1.068520 -0.942017 -0.034613
# C       -1.563857  2.096890  0.573401  1.035832  1.610257

# %%
pd.merge(df1, df2, left_index=True, right_index=True, suffixes=('_1', '_2'))
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A        0.927388 -1.372988 -1.068520 -0.942017 -0.034613
# C       -1.563857  2.096890  0.573401  1.035832  1.610257

# %%
pd.merge(df1, df2, left_index=True, right_index=True, suffixes=('_1', '_2'), how='outer')
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A        0.927388 -1.372988 -1.068520 -0.942017 -0.034613
# B             NaN       NaN  1.194072  0.365779  0.259961
# C       -1.563857  2.096890  0.573401  1.035832  1.610257
# D             NaN       NaN -0.334471 -0.224601  1.311413
# E       -1.235737 -1.230761       NaN       NaN       NaN

# %%
df1.merge(df2, left_index=True, right_index=True, suffixes=('_1', '_2'), how='outer')
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A        0.927388 -1.372988 -1.068520 -0.942017 -0.034613
# B             NaN       NaN  1.194072  0.365779  0.259961
# C       -1.563857  2.096890  0.573401  1.035832  1.610257
# D             NaN       NaN -0.334471 -0.224601  1.311413
# E       -1.235737 -1.230761       NaN       NaN       NaN

# %%
df1.join(df2, lsuffix='_1', rsuffix='_2')
# Out:
# Columns    colA_1    colB_1    colA_2    colB_2      colC
# Index
# A        0.927388 -1.372988 -1.068520 -0.942017 -0.034613
# C       -1.563857  2.096890  0.573401  1.035832  1.610257
# E       -1.235737 -1.230761       NaN       NaN       NaN

# %%
pd.concat([df1, df2])
# Out:
# Columns      colA      colB      colC
# Index
# A        0.927388 -1.372988       NaN
# C       -1.563857  2.096890       NaN
# E       -1.235737 -1.230761       NaN
# A       -1.068520 -0.942017 -0.034613
# B        1.194072  0.365779  0.259961
# C        0.573401  1.035832  1.610257
# D       -0.334471 -0.224601  1.311413

# %%
pd.concat([df1, df2], axis=1)
# Out:
# Columns      colA      colB      colA      colB      colC
# Index
# A        0.927388 -1.372988 -1.068520 -0.942017 -0.034613
# C       -1.563857  2.096890  0.573401  1.035832  1.610257
# E       -1.235737 -1.230761       NaN       NaN       NaN
# B             NaN       NaN  1.194072  0.365779  0.259961
# D             NaN       NaN -0.334471 -0.224601  1.311413

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
# Columns      colA      colB      colC
# 0        0.927388 -1.372988       NaN
# 1       -1.563857  2.096890       NaN
# 2       -1.235737 -1.230761       NaN
# 3       -1.068520 -0.942017 -0.034613
# 4        1.194072  0.365779  0.259961
# 5        0.573401  1.035832  1.610257
# 6       -0.334471 -0.224601  1.311413

# %%
# Hierarchial indexing

# %%
df = pd.DataFrame(np.random.randn(10, 2), index=[list('aaabbbccdd'), [1, 2, 3, 1, 2, 3, 1, 2, 1, 2]], columns=['A', 'B']); df
# Out:
#             A         B
# a 1 -1.696158  0.320092
#   2  0.057291 -1.386637
#   3  0.096861 -0.601504
# b 1  0.229043  1.247316
#   2  0.626056  0.785548
#   3 -0.316227  1.505282
# c 1 -0.220914 -1.236912
#   2  0.487231 -2.867846
# d 1 -1.294842  0.207469
#   2 -0.705740 -0.344436

# %%
df.index.names = ['alpha', 'numeric']; df
# Out:
#                       A         B
# alpha numeric
# a     1       -1.696158  0.320092
#       2        0.057291 -1.386637
#       3        0.096861 -0.601504
# b     1        0.229043  1.247316
#       2        0.626056  0.785548
#       3       -0.316227  1.505282
# c     1       -0.220914 -1.236912
#       2        0.487231 -2.867846
# d     1       -1.294842  0.207469
#       2       -0.705740 -0.344436

# %%
df.reset_index()
# Out:
#   alpha  numeric         A         B
# 0     a        1 -1.696158  0.320092
# 1     a        2  0.057291 -1.386637
# 2     a        3  0.096861 -0.601504
# 3     b        1  0.229043  1.247316
# 4     b        2  0.626056  0.785548
# 5     b        3 -0.316227  1.505282
# 6     c        1 -0.220914 -1.236912
# 7     c        2  0.487231 -2.867846
# 8     d        1 -1.294842  0.207469
# 9     d        2 -0.705740 -0.344436

# %%
df.unstack()
# Out:
#                 A                             B
# numeric         1         2         3         1         2         3
# alpha
# a       -1.696158  0.057291  0.096861  0.320092 -1.386637 -0.601504
# b        0.229043  0.626056 -0.316227  1.247316  0.785548  1.505282
# c       -0.220914  0.487231       NaN -1.236912 -2.867846       NaN
# d       -1.294842 -0.705740       NaN  0.207469 -0.344436       NaN

# %%
df.stack()
# Out:
# alpha  numeric
# a      1        A   -1.696158
#                 B    0.320092
#        2        A    0.057291
#                 B   -1.386637
#        3        A    0.096861
#                 B   -0.601504
# b      1        A    0.229043
#                 B    1.247316
#        2        A    0.626056
#                 B    0.785548
#        3        A   -0.316227
#                 B    1.505282
# c      1        A   -0.220914
#                 B   -1.236912
#        2        A    0.487231
#                 B   -2.867846
# d      1        A   -1.294842
#                 B    0.207469
#        2        A   -0.705740
#                 B   -0.344436
# dtype: float64

# %%
df.stack().index
# Out:
# MultiIndex([('a', 1, 'A'),
#             ('a', 1, 'B'),
#             ('a', 2, 'A'),
#             ('a', 2, 'B'),
#             ('a', 3, 'A'),
#             ('a', 3, 'B'),
#             ('b', 1, 'A'),
#             ('b', 1, 'B'),
#             ('b', 2, 'A'),
#             ('b', 2, 'B'),
#             ('b', 3, 'A'),
#             ('b', 3, 'B'),
#             ('c', 1, 'A'),
#             ('c', 1, 'B'),
#             ('c', 2, 'A'),
#             ('c', 2, 'B'),
#             ('d', 1, 'A'),
#             ('d', 1, 'B'),
#             ('d', 2, 'A'),
#             ('d', 2, 'B')],
#            names=['alpha', 'numeric', None])

# %%
# Grouping

# %%
df = df.reset_index(); df
# Out:
#   alpha  numeric         A         B
# 0     a        1 -1.696158  0.320092
# 1     a        2  0.057291 -1.386637
# 2     a        3  0.096861 -0.601504
# 3     b        1  0.229043  1.247316
# 4     b        2  0.626056  0.785548
# 5     b        3 -0.316227  1.505282
# 6     c        1 -0.220914 -1.236912
# 7     c        2  0.487231 -2.867846
# 8     d        1 -1.294842  0.207469
# 9     d        2 -0.705740 -0.344436

# %%
grouped = df[['A','B']].groupby(df['alpha']); grouped

# %%
grouped.describe()
# Out:
#           A                                                              \
#       count      mean       std       min       25%       50%       75%
# alpha
# a       3.0 -0.514002  1.023968 -1.696158 -0.819434  0.057291  0.077076
# b       3.0  0.179624  0.473081 -0.316227 -0.043592  0.229043  0.427549
# c       2.0  0.133158  0.500734 -0.220914 -0.043878  0.133158  0.310195
# d       2.0 -1.000291  0.416558 -1.294842 -1.147566 -1.000291 -0.853016
#
#                     B                                                    \
#             max count      mean       std       min       25%       50%
# alpha
# a      0.096861   3.0 -0.556016  0.854273 -1.386637 -0.994071 -0.601504
# b      0.626056   3.0  1.179382  0.364644  0.785548  1.016432  1.247316
# c      0.487231   2.0 -2.052379  1.153244 -2.867846 -2.460113 -2.052379
# d     -0.705740   2.0 -0.068484  0.390255 -0.344436 -0.206460 -0.068484
#
#
#             75%       max
# alpha
# a     -0.140706  0.320092
# b      1.376299  1.505282
# c     -1.644646 -1.236912
# d      0.069492  0.207469

# %%
grouped.apply(pd.DataFrame.unstack)
# Out:
# alpha
# a      A  0   -1.696158
#           1    0.057291
#           2    0.096861
#        B  0    0.320092
#           1   -1.386637
#           2   -0.601504
# b      A  3    0.229043
#           4    0.626056
#           5   -0.316227
#        B  3    1.247316
#           4    0.785548
#           5    1.505282
# c      A  6   -0.220914
#           7    0.487231
#        B  6   -1.236912
#           7   -2.867846
# d      A  8   -1.294842
#           9   -0.705740
#        B  8    0.207469
#           9   -0.344436
# dtype: float64

# %%
grouped[['A', 'B']].agg('mean')
# Out:
#               A         B
# alpha
# a     -0.514002 -0.556016
# b      0.179624  1.179382
# c      0.133158 -2.052379
# d     -1.000291 -0.068484

# %%
from scipy import stats
grouped[['A', 'B']].transform(stats.zscore)
# Out:
#           A         B
# 0 -1.413950  1.256049
# 1  0.683310 -1.190835
# 2  0.730639 -0.065214
# 3  0.127940  0.228172
# 4  1.155753 -1.322785
# 5 -1.283693  1.094613
# 6 -1.000000  1.000000
# 7  1.000000 -1.000000
# 8 -1.000000  1.000000
# 9  1.000000 -1.000000

# %%
# Data transformation and missing data

# %%
# Transforming axis indices

# %%
df2
# Out:
# Columns      colA      colB      colC
# Index
# A       -1.068520 -0.942017 -0.034613
# B        1.194072  0.365779  0.259961
# C        0.573401  1.035832  1.610257
# D       -0.334471 -0.224601  1.311413

# %%
df2.index = ['Alpha', 'Beta', 'Gamma', 'Delta']; df2
# Out:
# Columns      colA      colB      colC
# Alpha   -1.068520 -0.942017 -0.034613
# Beta     1.194072  0.365779  0.259961
# Gamma    0.573401  1.035832  1.610257
# Delta   -0.334471 -0.224601  1.311413

# %%
df2.index = df2.index.map(lambda x : x[:3]); df2
# Out:
# Columns      colA      colB      colC
# Alp     -1.068520 -0.942017 -0.034613
# Bet      1.194072  0.365779  0.259961
# Gam      0.573401  1.035832  1.610257
# Del     -0.334471 -0.224601  1.311413

# %%
df2.rename(index={'Alp': 0, 'Bet': 1, 'Gam': 2, 'Del': 3}, columns={'colA': 'A', 'colB': 'B', 'colC': 'C'})
# Out:
# Columns         A         B         C
# 0       -1.068520 -0.942017 -0.034613
# 1        1.194072  0.365779  0.259961
# 2        0.573401  1.035832  1.610257
# 3       -0.334471 -0.224601  1.311413

# %%
# Dealing with missing data

# %%
# Filtering

# %%
for row, col in [('Bet', 'colA'), ('Bet', 'colB'), ('Bet', 'colC'), ('Del', 'colB'), ('Gam', 'colC')]:
    df2.at[row, col] = np.NaN

df2
# Out:
# Columns      colA      colB      colC
# Alp     -1.068520 -0.942017 -0.034613
# Bet           NaN       NaN       NaN
# Gam      0.573401  1.035832       NaN
# Del     -0.334471       NaN  1.311413

# %%
df2.isnull()
# Out:
# Columns   colA   colB   colC
# Alp      False  False  False
# Bet       True   True   True
# Gam      False  False   True
# Del      False   True  False

# %%
df2.notnull()
# Out:
# Columns   colA   colB   colC
# Alp       True   True   True
# Bet      False  False  False
# Gam       True   True  False
# Del       True  False   True

# %%
df2.dropna(how='all')
# Out:
# Columns      colA      colB      colC
# Alp     -1.068520 -0.942017 -0.034613
# Gam      0.573401  1.035832       NaN
# Del     -0.334471       NaN  1.311413

# %%
df2.dropna(how='any')
# Out:
# Columns     colA      colB      colC
# Alp     -1.06852 -0.942017 -0.034613

# %%
# Filling in

# %%
df2
# Out:
# Columns      colA      colB      colC
# Alp     -1.068520 -0.942017 -0.034613
# Bet           NaN       NaN       NaN
# Gam      0.573401  1.035832       NaN
# Del     -0.334471       NaN  1.311413

# %%
df2.fillna(method='backfill', inplace=True); df2
# Out:
# Columns      colA      colB      colC
# Alp     -1.068520 -0.942017 -0.034613
# Bet      0.573401  1.035832  1.311413
# Gam      0.573401  1.035832  1.311413
# Del     -0.334471       NaN  1.311413

# %%
# Transformation using functions/mapping

# %%
df2['Category'] = ['HIGH', 'LOW', 'LOW', 'HIGH']; df2
# Out:
# Columns      colA      colB      colC Category
# Alp     -1.068520 -0.942017 -0.034613     HIGH
# Bet      0.573401  1.035832  1.311413      LOW
# Gam      0.573401  1.035832  1.311413      LOW
# Del     -0.334471       NaN  1.311413     HIGH

# %%
df2['Category'] = df2['Category'].map({'HIGH': 'H', 'LOW': 'L'}); df2
# Out:
# Columns      colA      colB      colC Category
# Alp     -1.068520 -0.942017 -0.034613        H
# Bet      0.573401  1.035832  1.311413        L
# Gam      0.573401  1.035832  1.311413        L
# Del     -0.334471       NaN  1.311413        H

# %%
df2.drop('Category', axis=1).applymap(np.exp)
# Out:
# Columns      colA      colB      colC
# Alp      0.343517  0.389841  0.965980
# Bet      1.774291  2.817450  3.711415
# Gam      1.774291  2.817450  3.711415
# Del      0.715717       NaN  3.711415

# %%
# Discretization

# %%
arr = np.random.randn(10); arr
# Out:
# array([ 2.10594888, -0.77050146, -0.64251501, -0.77051782, -2.13123035,
#        -0.20500599, -0.40336886,  1.29007218, -0.49464803,  0.20845665])

# %%
cat = pd.cut(arr, bins=5, labels=['Very Low', 'Low', 'Med', 'High', 'Very High']); cat
# Out:
# ['Very High', 'Low', 'Low', 'Low', 'Very Low', 'Med', 'Med', 'Very High', 'Low', 'Med']
# Categories (5, object): ['Very Low' < 'Low' < 'Med' < 'High' < 'Very High']

# %%
pd.DataFrame({'Value': arr, 'Category': cat})
# Out:
#       Value   Category
# 0  2.105949  Very High
# 1 -0.770501        Low
# 2 -0.642515        Low
# 3 -0.770518        Low
# 4 -2.131230   Very Low
# 5 -0.205006        Med
# 6 -0.403369        Med
# 7  1.290072  Very High
# 8 -0.494648        Low
# 9  0.208457        Med

# %%
qcat = pd.qcut(arr, q=5, labels=['Very Low', 'Low', 'Med', 'High', 'Very High']); qcat
# Out:
# ['Very High', 'Low', 'Low', 'Very Low', 'Very Low', 'High', 'Med', 'Very High', 'Med', 'High']
# Categories (5, object): ['Very Low' < 'Low' < 'Med' < 'High' < 'Very High']

# %%
pd.DataFrame({'Value': arr, 'Category': cat, 'Quartile Category': qcat})
# Out:
#       Value   Category Quartile Category
# 0  2.105949  Very High         Very High
# 1 -0.770501        Low               Low
# 2 -0.642515        Low               Low
# 3 -0.770518        Low          Very Low
# 4 -2.131230   Very Low          Very Low
# 5 -0.205006        Med              High
# 6 -0.403369        Med               Med
# 7  1.290072  Very High         Very High
# 8 -0.494648        Low               Med
# 9  0.208457        Med              High

# %%
pd.cut(arr, bins=5).categories
# Out:
# IntervalIndex([(-2.135, -1.284], (-1.284, -0.436], (-0.436, 0.411], (0.411, 1.259], (1.259, 2.106]], dtype='interval[float64, right]')

# %%
pd.qcut(arr, q=5).categories
# Out:
# IntervalIndex([(-2.1319999999999997, -0.771], (-0.771, -0.554], (-0.554, -0.324], (-0.324, 0.425], (0.425, 2.106]], dtype='interval[float64, right]')

# %%
# Permutations and sampling

# %%
df = pd.DataFrame(np.random.randn(10,5), index=np.sort(np.random.randint(0, 100, size=10)), columns=list('ABCDE')); df
# Out:
#            A         B         C         D         E
# 11  0.118546  1.210331 -0.121349 -1.462612  1.098241
# 18  1.320334  0.034842 -0.409043  1.399661 -1.022252
# 23 -2.535551 -1.420984  0.201383 -0.182211  0.658900
# 24  0.402205  0.745365  0.882053 -1.490881 -1.594225
# 43  0.212093  1.503611  0.682440  0.161681 -0.407339
# 51  0.477257 -1.525876 -1.673801 -1.927516 -0.117230
# 54  1.410940  1.156801  0.463907  0.021208 -0.920282
# 85 -0.637293 -0.240030 -0.118366  0.749428 -0.135794
# 90  2.085756 -1.456992 -1.280559 -1.311975 -0.316712
# 93 -0.723433 -0.435258  0.863352 -0.414496 -0.092212

# %%
df.loc[np.random.permutation(df.index)]
# Out:
#            A         B         C         D         E
# 24  0.402205  0.745365  0.882053 -1.490881 -1.594225
# 90  2.085756 -1.456992 -1.280559 -1.311975 -0.316712
# 93 -0.723433 -0.435258  0.863352 -0.414496 -0.092212
# 51  0.477257 -1.525876 -1.673801 -1.927516 -0.117230
# 85 -0.637293 -0.240030 -0.118366  0.749428 -0.135794
# 23 -2.535551 -1.420984  0.201383 -0.182211  0.658900
# 54  1.410940  1.156801  0.463907  0.021208 -0.920282
# 11  0.118546  1.210331 -0.121349 -1.462612  1.098241
# 43  0.212093  1.503611  0.682440  0.161681 -0.407339
# 18  1.320334  0.034842 -0.409043  1.399661 -1.022252

# %%
df.iloc[np.random.randint(0, len(df), size=5)]
# Out:
#            A         B         C         D         E
# 18  1.320334  0.034842 -0.409043  1.399661 -1.022252
# 24  0.402205  0.745365  0.882053 -1.490881 -1.594225
# 11  0.118546  1.210331 -0.121349 -1.462612  1.098241
# 54  1.410940  1.156801  0.463907  0.021208 -0.920282
# 23 -2.535551 -1.420984  0.201383 -0.182211  0.658900

# %%
# File operations and Pandas

# %%
# Text files

# %%
# Writing

# %%
df.to_csv('df.csv', sep=',', header=True, index=True)

# %%
# !head -n 4 df.csv
# Out:
# ,A,B,C,D,E
# 11,0.11854647411144734,1.2103311169902842,-0.12134920680003551,-1.4626124382674752,1.0982412600055458
# 18,1.320334056780627,0.034841791723272036,-0.40904312705913703,1.3996605195767597,-1.0222521649093024
# 23,-2.53555110216517,-1.4209844611887659,0.2013833398969539,-0.18221106901705877,0.6589004400924232

# %%
# Reading

# %%
pd.read_csv('df.csv', sep=',', index_col=0, nrows=5)
# Out:
#            A         B         C         D         E
# 11  0.118546  1.210331 -0.121349 -1.462612  1.098241
# 18  1.320334  0.034842 -0.409043  1.399661 -1.022252
# 23 -2.535551 -1.420984  0.201383 -0.182211  0.658900
# 24  0.402205  0.745365  0.882053 -1.490881 -1.594225
# 43  0.212093  1.503611  0.682440  0.161681 -0.407339

# %%
pd.read_csv('df.csv', sep=',', index_col=0, chunksize=2)

# %%
list(pd.read_csv('df.csv', sep=',', index_col=0, chunksize=2))
# Out:
# [           A         B         C         D         E
#  11  0.118546  1.210331 -0.121349 -1.462612  1.098241
#  18  1.320334  0.034842 -0.409043  1.399661 -1.022252,
#             A         B         C         D         E
#  23 -2.535551 -1.420984  0.201383 -0.182211  0.658900
#  24  0.402205  0.745365  0.882053 -1.490881 -1.594225,
#             A         B         C         D         E
#  43  0.212093  1.503611  0.682440  0.161681 -0.407339
#  51  0.477257 -1.525876 -1.673801 -1.927516 -0.117230,
#             A         B         C         D         E
#  54  1.410940  1.156801  0.463907  0.021208 -0.920282
#  85 -0.637293 -0.240030 -0.118366  0.749428 -0.135794,
#             A         B         C         D         E
#  90  2.085756 -1.456992 -1.280559 -1.311975 -0.316712
#  93 -0.723433 -0.435258  0.863352 -0.414496 -0.092212]

# %%
# JSON files

# %%
df.iloc[:4]
# Out:
#            A         B         C         D         E
# 11  0.118546  1.210331 -0.121349 -1.462612  1.098241
# 18  1.320334  0.034842 -0.409043  1.399661 -1.022252
# 23 -2.535551 -1.420984  0.201383 -0.182211  0.658900
# 24  0.402205  0.745365  0.882053 -1.490881 -1.594225

# %%
# df.iloc[:4].to_json('df.json')
df.iloc[:4].to_json('df.json', orient='records')

# %%
# !cat df.json
# Out:
# [{"A":0.1185464741,"B":1.210331117,"C":-0.1213492068,"D":-1.4626124383,"E":1.09824126},{"A":1.3203340568,"B":0.0348417917,"C":-0.4090431271,"D":1.3996605196,"E":-1.0222521649},{"A":-2.5355511022,"B":-1.4209844612,"C":0.2013833399,"D":-0.182211069,"E":0.6589004401},{"A":0.4022054774,"B":0.7453652163,"C":0.8820528402,"D":-1.4908813527,"E":-1.5942251072}]

# %%
pd.read_json('df.json')
# Out:
#           A         B         C         D         E
# 0  0.118546  1.210331 -0.121349 -1.462612  1.098241
# 1  1.320334  0.034842 -0.409043  1.399661 -1.022252
# 2 -2.535551 -1.420984  0.201383 -0.182211  0.658900
# 3  0.402205  0.745365  0.882053 -1.490881 -1.594225
